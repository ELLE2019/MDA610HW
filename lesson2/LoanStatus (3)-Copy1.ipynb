# %% [markdown]
# # Loan Data Analysis

# %% [markdown]
# - A loan status data set will be loaded and analyzed.
# - Data Dictionary
#     - Id: loan Id
#     - Married: marital status of the debtor
#     - Dependent: the number of people who claim the debtor as dependent
#     - Education: the debtor has a college degree or not
#     - SelfEmployed: the debtor is self-employed or not
#     - Income: the debtor's monthly income
#     - Loan: the balance of the loan in thousand dollars
#     - Status: Y - the debtor is repaying the loan; N - the debtor is not repaying the loan
# - Follow the *TODO* instruction to answer each question with a Python code snippet. After you finish answering all the questions, save the notebook with the necessary output for each code cell and then upload the notebook to Blackboard.

# %%
# initialization and data loading
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
frame = pd.read_csv(r'https://raw.githubusercontent.com/postmda/MDA610/master/Pages/LoanStatus.csv')

# %% [markdown]
# **TODO 1**
# `frame` is the DataFrame that contains the loan status data. Find the number of rows in the DataFrame.

# %%
#####TODO 1#####
pass
frame.shape[0]
# Out:
# 614

# %% [markdown]
# **TODO 2**
# Show the first eight rows of the DataFrame.

# %%
#####TODO 2#####
pass
frame.head(8)
# Out:
#          Id Married  Dependents     Education SelfEmployed  Income  Loan  \
# 0  LP001002      No         0.0      Graduate           No    5849    83
# 1  LP001003     Yes         1.0      Graduate           No    4583   128
# 2  LP001005     Yes         0.0      Graduate          Yes    3000    66
# 3  LP001006     Yes         0.0  Not Graduate           No    2583   120
# 4  LP001008      No         0.0      Graduate           No    6000   141
# 5  LP001011     Yes         2.0      Graduate          Yes    5417   267
# 6  LP001013     Yes         0.0  Not Graduate           No    2333    95
# 7  LP001014     Yes         5.0      Graduate           No    3036   158
#
#   Status
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
# 5      Y
# 6      Y
# 7      N

# %% [markdown]
# **TODO 3**
# Find the mean loan balance in thousand dollars.

# %%
#####TODO 3#####
pass
round(frame.Loan.mean())
# Out:
# 145

# %% [markdown]
# **TODO 4**
# Find the number of loans with a balance of at least 200 thousand dollars.

# %%
#####TODO 4#####
pass
rowl= frame.loc[frame.Loan>= 200]
rowl.shape[0]
# Out:
# 88

# %% [markdown]
# **TODO 5**
# Sort the DataFrame in ascending order of column `Loan`. Show the last four rows in the sorted DataFrame.

# %%
#####TODO 5#####
pass
sorted_loan = frame.sort_values(by='Loan',ascending=True)
sorted_loan.tail(4)
# Out:
#            Id Married  Dependents Education SelfEmployed  Income  Loan Status
# 155  LP001536     Yes         4.0  Graduate           No   39999   600      Y
# 561  LP002813     Yes         1.0  Graduate          Yes   19484   600      Y
# 130  LP001469      No         0.0  Graduate          Yes   20166   650      Y
# 171  LP001585     Yes         3.0  Graduate           No   51763   700      Y

# %% [markdown]
# **TODO 6**
# Find the number of debtors who are married and have a monthly income below 3000 dollars.

# %%
#####TODO 6#####
# 580  LP002892     Yes         2.0      Graduate           No    6540   205
# 582  LP002894     Yes         0.0      Graduate           No    3166    36
# 585  LP002912     Yes         1.0      Graduate           No    4283   172
# 591  LP002931     Yes         2.0      Graduate          Yes    6000   205
# 593  LP002936     Yes         0.0      Graduate           No    3859   142
# 594  LP002938     Yes         0.0      Graduate          Yes   16120   260
# 596  LP002941     Yes         2.0  Not Graduate          Yes    6383   187
# 598  LP002945     Yes         0.0      Graduate          Yes    9963   180
# 599  LP002948     Yes         2.0      Graduate           No    5780   192
# 602  LP002953     Yes         3.0      Graduate           No    5703   128
# 604  LP002959     Yes         1.0      Graduate           No   12000   496
# 606  LP002961     Yes         1.0      Graduate           No    3400   173
# 607  LP002964     Yes         2.0  Not Graduate           No    3987   157
# 608  LP002974     Yes         0.0      Graduate           No    3232   108
# 610  LP002979     Yes         3.0      Graduate           No    4106    40
# 611  LP002983     Yes         1.0      Graduate           No    8072   253
# 612  LP002984     Yes         2.0      Graduate           No    7583   187
#
#     Status
# 1        N
# 5        Y
# 7        N
# 8        Y
# 9        N
# 10       Y
# 12       Y
# 18       N
# 20       N
# 21       Y
# 23       N
# 24       N
# 25       Y
# 27       Y
# 30       N
# 33       Y
# 37       Y
# 43       Y
# 44       Y
# 46       Y
# 47       Y
# 53       N
# 54       N
# 57       N
# 58       Y
# 59       Y
# 61       Y
# 63       N
# 65       N
# 67       Y
# ..     ...
# 561      Y
# 562      Y
# 564      N
# 565      Y
# 567      N
# 569      N
# 570      Y
# 571      N
# 572      Y
# 573      N
# 574      N
# 575      Y
# 576      N
# 580      Y
# 582      Y
# 585      N
# 591      N
# 593      Y
# 594      Y
# 596      N
# 598      Y
# 599      Y
# 602      Y
# 604      Y
# 606      Y
# 607      Y
# 608      Y
# 610      Y
# 611      Y
# 612      Y
#
# [282 rows x 8 columns]

# %% [markdown]
# **TODO 7**
# Show columns `Id` and `Status` of the tenth, twelfth and thirteenth rows in the DataFrame.

# %%
#####TODO 7#####
pass
#pd.DataFrame([9,11,13] , columns =['Id','Status'])
frame.iloc[[9,11,12],[0,7]]
# Out:
#           Id Status
# 9   LP001020      N
# 11  LP001027      Y
# 12  LP001028      Y

# %% [markdown]
# **TODO 8** Find the highest monthly income of the debtors who are repaying their loans.

# %%
#####TODO 8#####
pass
#frame.Income.value_counts().loc['Status' == 'Y']
frame[frame.Status == 'Y'].Income.max()
# Out:
# 63337

# %% [markdown]
# **TODO 9**
# Return the index of the row with the lowest loan balance.

# %%
#####TODO 9#####
pass
frame['Loan'].idxmin()
# Out:
# 568

# %% [markdown]
# **TODO 10** Find the number of rows with missing values.

# %%
#####TODO 10#####
pass
np.sum(frame.isnull().sum())
# Out:
# 37
